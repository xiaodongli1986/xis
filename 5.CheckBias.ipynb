# %% [raw]
# # To avoid problem of bias we can impose cut on length
# ### Because it is related with the problem of shot noise
# # It is not helpful to impose cut on imumin (i.e. that is not very related with FOG)
# # It is helpful to have 2pcf measured on large scales!

# %%
execfile('/home/xiaodongli/software/pythonlib/Tpcftools.py')
execfile('/home/xiaodongli/software/pythonlib/bossdatamock.py')
datamockdir = datamockdir_local
# %pylab inline
# Out:
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'ws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'omws' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'scanname' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'oms' is assigned to before global declaration
#   global oms, ws, omws, scanname
# /home/xiaodongli/software/pythonlib/Tpcftools_smuintxi.py:513: SyntaxWarning: name 'ws' is assigned to before global declaration
# ...

# %% [raw]
# ### Dependence on halo bias
# ### Increase imumin does not help to decrease the redshift evolution
# ### Increase smin to ~12 significantly avoid the effect

# %%
datafiles = getfilelist('/home/xiaodongli/SparseFilaments/data/local_input/HR4/2pcf_of_diff_mass_cut/*.2pcf')
legs =    [  '$M\\ >\\ 1\\times 10^{13} M_{\\odot},\\ \\bar n = 4.56\\times10 ^ {-4} ({\\it h^{-1}}{\\rm Mpc})^{-3}$',
             '$M\\ >\\ 2\\times 10^{13} M_{\\odot},\\ \\bar n = 2.10\\times10 ^ {-4} ({\\it h^{-1}}{\\rm Mpc})^{-3}$',
             '$M\\ >\\ 4\\times 10^{13} M_{\\odot},\\ \\bar n = 0.91\\times10 ^ {-4} ({\\it h^{-1}}{\\rm Mpc})^{-3}$',
            ]

s1, s2 = 18, 50
for s1 in [5,10,15]:
#for imumin in [1,30,60]:
 print 's1 = ', s1
 ifile = 0
 fig1, ax1 = figax(16,4)
 fig2, ax2 = figax(16,4)
 for nowfile in datafiles:
    X = smu_smids(s1,s2)
    Y = smu_xis(nowfile, imumin=imumin, sfact=1, make_plot=False); 
    Y =Y[s1:s2];
    Y =normto1(Y)
    ax1.plot(X,Y,label=legs[ifile])
    if ifile == 0:
        Ysave = [y for y in Y]
        ifile +=1
        continue
    else:
        diffY = [Y[row]-Ysave[row] for row in range(len(Y))]
        ax2.plot(X,diffY,label=legs[ifile])
    ifile+=1
 for ax in [ax1, ax2]:
        ax.grid()
        ax.legend(frameon=False, fontsize=16)
 
        #ax1.text(8, 0.35, 'Dependence on halo mass, measured from HR4 mock galaxies', fontsize=18)
 ax1.set_ylabel('$s\\ \\xi (s)$',fontsize=24)
 ax2.set_ylabel('$\\delta\\ s\\ \\xi (s)$',fontsize=24)
 ax2.set_ylim(-0.1,0.18)
 plt.show()
# Out:
# s1 =  5
# s1 =  10
# s1 =  15
